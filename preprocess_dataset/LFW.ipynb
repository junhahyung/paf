# %% [markdown]
# # THIS DATA DOES NOT HAVE FACIAL LANDMARK

# %%
import os
import sys
sys.path.append('../')

import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
from TFRHelper import *

# %%
ds = tfds.load('lfw', split='train')
iterator = ds.as_numpy_iterator()

# %%
dt = iterator.next()

# %%
image = dt['image']
print(dt['label'])
plt.imshow(image)
# Out:
# b'Justin_Timberlake'
